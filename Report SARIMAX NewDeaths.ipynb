# %% [markdown]
# # SARIMAX (seasonal autoregressive integrated moving average with exogenous regressors) Model

# %% [markdown]
# ## Import data, handle missing values, create a clean dataframe

# %%
import pandas as pd
import numpy as np
# import seaborn as sns
from math import floor, sqrt
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

ic = pd.read_excel("D:\DS\Mine\Corona\I22-01.xlsx", index_col=0, parse_dates=[0]) # Iran Corona
ic['total_vaccinations_f'] = ic['total_vaccinations'].interpolate(method='linear').fillna(0)
ic['stringency_index_f'] = ic['stringency_index'].fillna(method="ffill")
icf = ic.loc[ : , ['total_cases', 'new_cases', 'new_cases_smoothed',
                   'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_vaccinations_f', 'stringency_index_f']]
icf = icf.asfreq(None)
pd.options.display.float_format = '{:,.2f}'.format
# pd.set_option('display.max_rows', 2000)
icf
# Out:
#             total_cases  new_cases  new_cases_smoothed  total_deaths  \
# date
# 2020-02-19            2          2                 NaN             2
# 2020-02-20            5          3                 NaN             2
# 2020-02-21           18         13                 NaN             4
# 2020-02-22           28         10                 NaN             5
# 2020-02-23           43         15                 NaN             8
# ...                 ...        ...                 ...           ...
# 2021-12-28      6188857       2128            1,867.86        131474
# 2021-12-29      6190762       1905            1,839.57        131527
# 2021-12-30      6192698       1936            1,840.14        131572
# 2021-12-31      6194401       1703            1,802.43        131606
# 2022-01-01      6195403       1002            1,785.43        131639
#
#             new_deaths  new_deaths_smoothed  total_vaccinations_f  \
# date
# 2020-02-19           2                  NaN                  0.00
# 2020-02-20           0                  NaN                  0.00
# 2020-02-21           2                  NaN                  0.00
# 2020-02-22           1                  NaN                  0.00
# 2020-02-23           3                  NaN                  0.00
# ...                ...                  ...                   ...
# 2021-12-28          40                43.86        116,210,697.00
# 2021-12-29          53                45.14        116,210,697.00
# 2021-12-30          45                44.29        116,210,697.00
# 2021-12-31          34                42.86        116,210,697.00
# 2022-01-01          33                41.57        116,210,697.00
#
#             stringency_index_f
# date
# 2020-02-19                0.00
# 2020-02-20                2.78
# 2020-02-21                2.78
# 2020-02-22               11.11
# 2020-02-23               11.11
# ...                        ...
# 2021-12-28               61.57
# 2021-12-29               61.57
# 2021-12-30               61.57
# 2021-12-31               61.57
# 2022-01-01               61.57
#
# [683 rows x 8 columns]

# %% [markdown]
# ## Defining constants, spliting train and test

# %%
length = icf.shape[0]                #number of records
train_len = floor(length * 0.85)     #of records are going to be used for training
print('Out of', length, 'samples,', train_len, 'samples were devoted to training section and the rest (i.e.',
      length - train_len, 'samples) to test section.')
prl = 28   #4 weeks                                    #prediction lendth: number of days to predict

icn = icf.loc[:,'new_deaths']
xd = icn.values
xr = xd[:train_len]
xs = xd[train_len:train_len+prl]
xsp = []
# Out:
# Out of 683 samples, 580 samples were devoted to training section and the rest (i.e. 103 samples) to test section.

# %% [markdown]
# ## Checking stationarity

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(xr)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -3.937050
# p-value: 0.001778

# %% [markdown]
# p-value < 0.05 so the data is stationary.

# %% [markdown]
# ## Models

# %% [markdown]
# ### Model 1: Auto ARIMA (Seasonal)

# %%
# The following line will make it possible to zoom and pan on graphs:
# %matplotlib notebook

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
res = seasonal_decompose(icf['new_deaths'])
# res.plot();
# res.seasonal.plot(figsize=(9, 8));

# %%
res.seasonal.head(15)
# Out:
# date
# 2020-02-19     3.21
# 2020-02-20     3.61
# 2020-02-21   -11.83
# 2020-02-22   -16.65
# 2020-02-23     4.27
# 2020-02-24     9.42
# 2020-02-25     7.96
# 2020-02-26     3.21
# 2020-02-27     3.61
# 2020-02-28   -11.83
# 2020-02-29   -16.65
# 2020-03-01     4.27
# 2020-03-02     9.42
# 2020-03-03     7.96
# 2020-03-04     3.21
# Freq: D, Name: seasonal, dtype: float64

# %% [markdown]
# The seasonality period extracted by seasonal_decompose is 7 days.

# %%
seasonality_period = 7
weeks_per_year = 365 // seasonality_period  #Floor division
print('There are approximately', weeks_per_year, 'weeks per year.')
# Out:
# There are approximately 52 weeks per year.

# %%
# pip install pmdarima # if you don't have pmdarima

# %%
from pmdarima import auto_arima
auto_arima(xr, m=weeks_per_year, trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[52] intercept   : AIC=5502.006, Time=7.30 sec
#  ARIMA(0,1,0)(0,0,0)[52] intercept   : AIC=5553.598, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[52] intercept   : AIC=5516.408, Time=1.16 sec
#  ARIMA(0,1,1)(0,0,1)[52] intercept   : AIC=5505.756, Time=1.72 sec
#  ARIMA(0,1,0)(0,0,0)[52]             : AIC=5551.836, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[52] intercept   : AIC=5505.642, Time=5.43 sec
#  ARIMA(2,1,2)(1,0,0)[52] intercept   : AIC=5505.167, Time=5.98 sec
#  ARIMA(2,1,2)(2,0,1)[52] intercept   : AIC=5500.628, Time=34.04 sec
#  ARIMA(2,1,2)(2,0,0)[52] intercept   : AIC=5500.638, Time=28.00 sec
#  ARIMA(2,1,2)(2,0,2)[52] intercept   : AIC=inf, Time=33.92 sec
#  ARIMA(2,1,2)(1,0,2)[52] intercept   : AIC=5499.261, Time=30.32 sec
#  ARIMA(2,1,2)(0,0,2)[52] intercept   : AIC=5501.842, Time=24.93 sec
#  ARIMA(1,1,2)(1,0,2)[52] intercept   : AIC=5500.792, Time=16.94 sec
#  ARIMA(2,1,1)(1,0,2)[52] intercept   : AIC=5500.574, Time=16.30 sec
#  ARIMA(3,1,2)(1,0,2)[52] intercept   : AIC=5482.191, Time=36.68 sec
#  ARIMA(3,1,2)(0,0,2)[52] intercept   : AIC=5483.667, Time=30.18 sec
#  ARIMA(3,1,2)(1,0,1)[52] intercept   : AIC=5484.403, Time=8.38 sec
#  ARIMA(3,1,2)(2,0,2)[52] intercept   : AIC=inf, Time=40.95 sec
#  ARIMA(3,1,2)(0,0,1)[52] intercept   : AIC=5488.436, Time=8.62 sec
#  ARIMA(3,1,2)(2,0,1)[52] intercept   : AIC=5482.887, Time=36.08 sec
#  ARIMA(3,1,1)(1,0,2)[52] intercept   : AIC=5492.889, Time=28.35 sec
#  ARIMA(4,1,2)(1,0,2)[52] intercept   : AIC=5424.484, Time=41.44 sec
#  ARIMA(4,1,2)(0,0,2)[52] intercept   : AIC=5470.596, Time=32.79 sec
#  ARIMA(4,1,2)(1,0,1)[52] intercept   : AIC=inf, Time=11.91 sec
#  ARIMA(4,1,2)(2,0,2)[52] intercept   : AIC=inf, Time=46.27 sec
#  ARIMA(4,1,2)(0,0,1)[52] intercept   : AIC=5427.365, Time=10.66 sec
#  ARIMA(4,1,2)(2,0,1)[52] intercept   : AIC=5425.257, Time=41.97 sec
#  ARIMA(4,1,1)(1,0,2)[52] intercept   : AIC=5494.329, Time=31.87 sec
#  ARIMA(5,1,2)(1,0,2)[52] intercept   : AIC=5479.725, Time=39.46 sec
#  ARIMA(4,1,3)(1,0,2)[52] intercept   : AIC=5478.233, Time=41.51 sec
#  ARIMA(3,1,3)(1,0,2)[52] intercept   : AIC=inf, Time=41.44 sec
#  ARIMA(5,1,1)(1,0,2)[52] intercept   : AIC=5489.659, Time=32.19 sec
#  ARIMA(5,1,3)(1,0,2)[52] intercept   : AIC=5435.095, Time=47.00 sec
#  ARIMA(4,1,2)(1,0,2)[52]             : AIC=5423.215, Time=37.37 sec
#  ARIMA(4,1,2)(0,0,2)[52]             : AIC=5423.432, Time=32.94 sec
#  ARIMA(4,1,2)(1,0,1)[52]             : AIC=5480.255, Time=10.48 sec
#  ARIMA(4,1,2)(2,0,2)[52]             : AIC=inf, Time=44.58 sec
#  ARIMA(4,1,2)(0,0,1)[52]             : AIC=5424.347, Time=6.03 sec
#  ARIMA(4,1,2)(2,0,1)[52]             : AIC=5423.535, Time=40.94 sec
#  ARIMA(3,1,2)(1,0,2)[52]             : AIC=5480.534, Time=29.44 sec
#  ARIMA(4,1,1)(1,0,2)[52]             : AIC=5492.980, Time=19.65 sec
#  ARIMA(5,1,2)(1,0,2)[52]             : AIC=5477.426, Time=37.91 sec
#  ARIMA(4,1,3)(1,0,2)[52]             : AIC=5476.325, Time=35.49 sec
#  ARIMA(3,1,1)(1,0,2)[52]             : AIC=5491.590, Time=18.35 sec
#  ARIMA(3,1,3)(1,0,2)[52]             : AIC=inf, Time=39.69 sec
#  ARIMA(5,1,1)(1,0,2)[52]             : AIC=5488.541, Time=23.07 sec
#  ARIMA(5,1,3)(1,0,2)[52]             : AIC=5434.551, Time=49.92 sec
#
# Best model:  ARIMA(4,1,2)(1,0,2)[52]
# Total fit time: 1239.733 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  580
# Model:             SARIMAX(4, 1, 2)x(1, 0, 2, 52)   Log Likelihood               -2701.608
# Date:                            Sat, 08 Jan 2022   AIC                           5423.215
# Time:                                    10:23:11   BIC                           5466.828
# Sample:                                         0   HQIC                          5440.220
#                                             - 580
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2731      0.046     27.959      0.000       1.184       1.362
# ar.L2         -0.3564      0.049     -7.221      0.000      -0.453      -0.260
# ar.L3         -0.1052      0.045     -2.354      0.019      -0.193      -0.018
# ar.L4          0.1277      0.038      3.361      0.001       0.053       0.202
# ma.L1         -1.7126      0.039    -44.291      0.000      -1.788      -1.637
# ma.L2          0.8020      0.037     21.831      0.000       0.730       0.874
# ar.S.L52      -0.4893      0.462     -1.058      0.290      -1.396       0.417
# ma.S.L52       0.4797      0.459      1.045      0.296      -0.420       1.379
# ma.S.L104      0.1136      0.056      2.038      0.042       0.004       0.223
# sigma2       688.6106     28.820     23.894      0.000     632.125     745.096
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               240.04
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.03   Skew:                             0.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Auto ARIMA found the following parameters as the best model:
# SARIMAX(4, 1, 2)x(1, 0, 2, 52)

# %%
enforce_stationary=False
enforce_invertibility=False

sm = SARIMAX(xr, order=(4, 1, 2), seasonal_order=(1, 0, 2, 52))
sm_fit = sm.fit()
sm_fit = sm.fit(maxiter=500)
auto_arima_pr = sm_fit.predict(start=train_len, end=train_len+prl-1)
auto_arima_pr_df = pd.DataFrame(auto_arima_pr, index=icn.iloc[train_len:train_len+prl].index, columns=['Auto ARIMA'])
sm_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  580
# Model:             SARIMAX(4, 1, 2)x(1, 0, 2, 52)   Log Likelihood               -2701.227
# Date:                            Wed, 12 Jan 2022   AIC                           5422.454
# Time:                                    15:41:00   BIC                           5466.067
# Sample:                                         0   HQIC                          5439.459
#                                             - 580
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2754      0.043     29.385      0.000       1.190       1.360
# ar.L2         -0.3526      0.047     -7.462      0.000      -0.445      -0.260
# ar.L3         -0.1059      0.043     -2.483      0.013      -0.190      -0.022
# ar.L4          0.1258      0.036      3.484      0.000       0.055       0.197
# ma.L1         -1.7159      0.037    -46.975      0.000      -1.788      -1.644
# ma.L2          0.8043      0.035     23.173      0.000       0.736       0.872
# ar.S.L52      -0.5331      0.406     -1.313      0.189      -1.329       0.263
# ma.S.L52       0.5264      0.402      1.308      0.191      -0.262       1.315
# ma.S.L104      0.1140      0.054      2.102      0.036       0.008       0.220
# sigma2       656.2882     26.026     25.216      0.000     605.278     707.299
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               238.41
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.02   Skew:                             0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Model 2: ARIMA (using the best parameters found in the previous study of ARIMA)

# %%
from statsmodels.tsa.arima.model import ARIMA
sm = ARIMA(xr, order=(6, 1, 2))
sm_fit = sm.fit()
arima_pr = sm_fit.predict(start=train_len, end=train_len+prl-1)
arima_pr_df = pd.DataFrame(arima_pr, index=icn.iloc[train_len:train_len+prl].index, columns=['Simple ARIMA'])
sm_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                 ARIMA(6, 1, 2)   Log Likelihood               -2682.384
# Date:                Wed, 12 Jan 2022   AIC                           5382.769
# Time:                        15:39:12   BIC                           5422.021
# Sample:                             0   HQIC                          5398.073
#                                 - 580
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8817      0.055     16.167      0.000       0.775       0.989
# ar.L2         -0.2460      0.045     -5.457      0.000      -0.334      -0.158
# ar.L3         -0.0575      0.036     -1.619      0.105      -0.127       0.012
# ar.L4          0.1404      0.040      3.490      0.000       0.062       0.219
# ar.L5         -0.1918      0.036     -5.370      0.000      -0.262      -0.122
# ar.L6          0.3589      0.029     12.445      0.000       0.302       0.415
# ma.L1         -1.3047      0.059    -22.006      0.000      -1.421      -1.189
# ma.L2          0.5045      0.055      9.155      0.000       0.396       0.612
# sigma2       616.7992     27.112     22.750      0.000     563.660     669.938
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):               109.89
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.52   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Model 3: SARIMAX (using vaccination and stringency as exogenous data)

# %% [markdown]
# #### Estimation of exogenous data:

# %%
# Vaccination:

from scipy.optimize import curve_fit
vac_pr_days = 30    #number of days to be used for curve fitting prior to the test date 

def func(x, a, b, c, d, e):
#     return a * x ** 4 + b * x ** 3 + c * x ** 2 + d * x + e
#     return a * x ** 3 + b * x ** 2 + c * x + d
    return a * x ** 2 + b * x + c
#     return a * x + b

xdata = list(range(vac_pr_days))
ydata = icf.iloc[train_len - vac_pr_days:train_len, 6].values

popt = curve_fit(func, xdata, ydata)[0]
y_hat = [func(x, popt[0], popt[1], popt[2], popt[3], popt[4]) for x in range(vac_pr_days, vac_pr_days + prl)]

ydata_test = icf.iloc[train_len:train_len + prl, 6].values
print('MAE:  Mean Absolute Error =           ', "{:2.0f}".format(mean_absolute_error(ydata_test, y_hat)))
print('MAPE: Mean Absolute Percentage Error =', "{:2.2%}".format(mean_absolute_percentage_error(ydata_test, y_hat)))
print('RMSE: Root Mean Squared Error =       ', "{:2.0f}".format(sqrt(mean_squared_error(ydata_test, y_hat))))
# Out:
# MAE:  Mean Absolute Error =            5620602
# MAPE: Mean Absolute Percentage Error = 8.61%
# RMSE: Root Mean Squared Error =        7210436
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# Considering the error metrics, the model looks a reasonable estimation of vaccination. The warning is due to having 2 extra parameters for curve fitting function (func). It's for more flexibility in changing the model to linear, quadratic, cubic or power 4.

# %% [markdown]
# Assigning values to test section for vaccination and stringency:
#     vaccination: predicted values
#     stringency: we assume the same last value continues

# %% [markdown]
# #### Assignment:

# %%
icf['total_vaccination_pr'] = np.zeros(length)
for x in range(train_len,train_len+prl):
    icf.iloc[x, 8] = y_hat[x - train_len]
icf['stringency_index_pr'] = np.zeros(length)
icf.iloc[train_len:train_len+prl, 9] = icf.iloc[train_len, 7]
icf.iloc[train_len:train_len+prl, 6:10]
# Comparing the actual values and predictions:
# Out:
#             total_vaccinations_f  stringency_index_f  total_vaccination_pr  \
# date
# 2021-09-21         44,597,771.86               74.54         45,048,695.84
# 2021-09-22         45,823,273.71               74.54         46,256,042.54
# 2021-09-23         47,048,775.57               74.54         47,493,564.25
# 2021-09-24         48,274,277.43               74.54         48,761,260.97
# 2021-09-25         49,499,779.29               74.54         50,059,132.69
# 2021-09-26         50,725,281.14               74.54         51,387,179.42
# 2021-09-27         51,950,783.00               74.54         52,745,401.15
# 2021-09-28         52,905,075.83               74.54         54,133,797.88
# 2021-09-29         53,859,368.67               74.54         55,552,369.63
# 2021-09-30         54,813,661.50               74.54         57,001,116.37
# 2021-10-01         55,767,954.33               74.54         58,480,038.12
# 2021-10-02         56,722,247.17               74.54         59,989,134.88
# 2021-10-03         57,676,540.00               74.54         61,528,406.65
# 2021-10-04         58,637,244.43               74.54         63,097,853.41
# 2021-10-05         59,597,948.86               74.54         64,697,475.19
# 2021-10-06         60,558,653.29               74.54         66,327,271.97
# 2021-10-07         61,519,357.71               74.54         67,987,243.75
# 2021-10-08         62,480,062.14               74.54         69,677,390.54
# 2021-10-09         63,440,766.57               74.54         71,397,712.33
# 2021-10-10         64,401,471.00               74.54         73,148,209.13
# 2021-10-11         65,615,497.12               74.54         74,928,880.94
# 2021-10-12         66,829,523.25               74.54         76,739,727.75
# 2021-10-13         68,043,549.38               74.54         78,580,749.56
# 2021-10-14         69,257,575.50               74.54         80,451,946.39
# 2021-10-15         70,471,601.62               74.54         82,353,318.21
# 2021-10-16         71,685,627.75               74.54         84,284,865.04
# 2021-10-17         72,899,653.88               74.54         86,246,586.88
# 2021-10-18         74,113,680.00               74.54         88,238,483.72
#
#             stringency_index_pr
# date
# 2021-09-21                74.54
# 2021-09-22                74.54
# 2021-09-23                74.54
# 2021-09-24                74.54
# 2021-09-25                74.54
# 2021-09-26                74.54
# 2021-09-27                74.54
# 2021-09-28                74.54
# 2021-09-29                74.54
# 2021-09-30                74.54
# 2021-10-01                74.54
# 2021-10-02                74.54
# 2021-10-03                74.54
# 2021-10-04                74.54
# 2021-10-05                74.54
# 2021-10-06                74.54
# 2021-10-07                74.54
# 2021-10-08                74.54
# 2021-10-09                74.54
# 2021-10-10                74.54
# 2021-10-11                74.54
# 2021-10-12                74.54
# 2021-10-13                74.54
# 2021-10-14                74.54
# 2021-10-15                74.54
# 2021-10-16                74.54
# 2021-10-17                74.54
# 2021-10-18                74.54

# %%
# Column 6: total_vaccinations_f
# Column 7: stringency_index_f
sm = SARIMAX(xr, order=(4, 1, 2), seasonal_order=(1, 0, 2, 52), exog=icf.iloc[:train_len, 6:8]) 
enforce_stationary=False
enforce_invertibility=False
sm.k_exog = 2
sm_fit = sm.fit(maxiter=500)
srx_pr_df = sm_fit.predict(start=train_len, end=train_len+prl-1, exog=icf.iloc[train_len:train_len + prl, 8:10])
sm_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  580
# Model:             SARIMAX(4, 1, 2)x(1, 0, 2, 52)   Log Likelihood               -2782.062
# Date:                            Wed, 12 Jan 2022   AIC                           5588.124
# Time:                                    11:19:15   BIC                           5640.460
# Sample:                                02-19-2020   HQIC                          5608.530
#                                      - 09-20-2021
# Covariance Type:                              opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# total_vaccinations_f -3.436e-06   3.29e-06     -1.043      0.297   -9.89e-06    3.02e-06
# stringency_index_f       0.7467      0.495      1.508      0.132      -0.224       1.717
# ar.L1                -7.539e-21      0.016  -4.65e-19      1.000      -0.032       0.032
# ar.L2                -1.174e-21      0.015  -7.75e-20      1.000      -0.030       0.030
# ar.L3                -2.193e-21      0.030  -7.22e-20      1.000      -0.060       0.060
# ar.L4                 3.269e-21      0.032   1.03e-19      1.000      -0.062       0.062
# ma.L1                -7.539e-21      0.016  -4.63e-19      1.000      -0.032       0.032
# ma.L2                -1.175e-21      0.015  -7.75e-20      1.000      -0.030       0.030
# ar.S.L52                -0.0209      0.179     -0.117      0.907      -0.371       0.329
# ma.S.L52                 0.1379      0.160      0.863      0.388      -0.175       0.451
# ma.S.L104                0.3169      0.042      7.578      0.000       0.235       0.399
# sigma2                 760.4938     30.232     25.155      0.000     701.240     819.747
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.09   Jarque-Bera (JB):               539.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.77   Skew:                             0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.21e+21. Standard errors may be unstable.
# """

# %% [markdown]
# ### Model 4: ARIMAX (using vaccination and stringency as exogenous data, but no seasonality)

# %%
# Column 6: total_vaccinations_f
# Column 7: stringency_index_f
sm = SARIMAX(xr, order=(6, 1, 2), exog=icf.iloc[:train_len, 6:8]) 
enforce_stationary=False
enforce_invertibility=False
sm.k_exog = 2
sm_fit = sm.fit(maxiter=500)
arx_pr_df = sm_fit.predict(start=train_len, end=train_len+prl-1, exog=icf.iloc[train_len:train_len + prl, 8:10])
sm_fit.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:               SARIMAX(6, 1, 2)   Log Likelihood               -2740.460
# Date:                Wed, 12 Jan 2022   AIC                           5502.920
# Time:                        11:22:58   BIC                           5550.894
# Sample:                    02-19-2020   HQIC                          5521.625
#                          - 09-20-2021
# Covariance Type:                  opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# total_vaccinations_f -3.436e-06   2.03e-06     -1.695      0.090   -7.41e-06    5.38e-07
# stringency_index_f       0.7467      0.622      1.201      0.230      -0.472       1.966
# ar.L1                   -0.1347      3.669     -0.037      0.971      -7.326       7.056
# ar.L2                   -0.0389      1.249     -0.031      0.975      -2.486       2.408
# ar.L3                   -0.0962      0.631     -0.153      0.879      -1.332       1.140
# ar.L4                    0.0523      0.552      0.095      0.925      -1.031       1.135
# ar.L5                   -0.1317      0.061     -2.172      0.030      -0.250      -0.013
# ar.L6                    0.0225      0.506      0.044      0.965      -0.969       1.014
# ma.L1                   -0.1451      3.650     -0.040      0.968      -7.299       7.009
# ma.L2                   -0.0773      0.289     -0.267      0.789      -0.644       0.490
# sigma2                 760.4938     42.821     17.760      0.000     676.566     844.421
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               398.65
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.03   Skew:                             0.73
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.5e+14. Standard errors may be unstable.
# """

# %% [markdown]
# ## Errors and plots

# %%
print('Auto ARIMA')
print('MAE:  Mean Absolute Error =           ', "{:2.2f}".format(mean_absolute_error(xs, auto_arima_pr)))
print('MAPE: Mean Absolute Percentage Error =', "{:2.1%}".format(mean_absolute_percentage_error(xs, auto_arima_pr)))
print('RMSE: Root Mean Squared Error =       ', "{:2.2f}".format(sqrt(mean_squared_error(xs, auto_arima_pr))))
print('Simple ARIMA')
print('MAE:  Mean Absolute Error =           ', "{:2.2f}".format(mean_absolute_error(xs, arima_pr)))
print('MAPE: Mean Absolute Percentage Error =', "{:2.1%}".format(mean_absolute_percentage_error(xs, arima_pr)))
print('RMSE: Root Mean Squared Error =       ', "{:2.2f}".format(sqrt(mean_squared_error(xs, arima_pr))))
srx_pr = srx_pr_df.values
print('SARIMAX')
print('MAE:  Mean Absolute Error =           ', "{:2.2f}".format(mean_absolute_error(xs, srx_pr)))
print('MAPE: Mean Absolute Percentage Error =', "{:2.1%}".format(mean_absolute_percentage_error(xs, srx_pr)))
print('RMSE: Root Mean Squared Error =       ', "{:2.2f}".format(sqrt(mean_squared_error(xs, srx_pr))))
arx_pr = arx_pr_df.values
print('ARIMAX')
print('MAE:  Mean Absolute Error =           ', "{:2.2f}".format(mean_absolute_error(xs, arx_pr)))
print('MAPE: Mean Absolute Percentage Error =', "{:2.1%}".format(mean_absolute_percentage_error(xs, arx_pr)))
print('RMSE: Root Mean Squared Error =       ', "{:2.2f}".format(sqrt(mean_squared_error(xs, arx_pr))))

fig, ax = plt.subplots(figsize=(9, 5))
ax.set(title='New deaths', xlabel='Date', ylabel='Person')
icf.iloc[train_len-3:train_len+prl + 3,4].plot(ax=ax, style='r', label='Actual new deaths')
auto_arima_pr_df.plot(ax=ax, style='g--', label='Auto ARIMA')
arima_pr_df.plot(ax=ax, style='m--', label='Simple ARIMA')
srx_pr_df.plot(ax=ax, style='b--', label='SARIMAX')
arx_pr_df.plot(ax=ax, style='c--', label='ARIMAX')
legend = ax.legend(loc='lower left')
# Out:
# Auto ARIMA
# MAE:  Mean Absolute Error =            24.35
# MAPE: Mean Absolute Percentage Error = 11.1%
# RMSE: Root Mean Squared Error =        29.42
# Simple ARIMA
# MAE:  Mean Absolute Error =            24.79
# MAPE: Mean Absolute Percentage Error = 10.6%
# RMSE: Root Mean Squared Error =        30.63
# SARIMAX
# MAE:  Mean Absolute Error =            51.28
# MAPE: Mean Absolute Percentage Error = 23.1%
# RMSE: Root Mean Squared Error =        55.57
# ARIMAX
# MAE:  Mean Absolute Error =            52.58
# MAPE: Mean Absolute Percentage Error = 23.0%
# RMSE: Root Mean Squared Error =        57.06
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this part of the study, we used four models and compared the concept, implementation and the performance of the models. The ARIMA model with (p, d, q) parameters, can deliver good estimation of the studied values. Seasonality of the data was observed using seasonal_decompose. The Auto ARIMA using the pmdarima library conducts a search on the parameters. It also takes seasonality input and find the best model. In the SARIMAX model, we have used total_vaccination and stringency_index as exogenous data. And finally in ARIMAX, seasonality was ignored, and the total_vaccination and stringency_index were used as  exogenous data.
#
# The performance of the models was investigated in a single section of the test data. The results does not show improvement of the models using exogenous features in SARIMAX model over SARIMA or ARIMA. Both of the exogenous features have long term effects on the studied values. This implies that the use of total_vaccination and stringency_index as exogenous data requires furthur investigation on how to use them.
